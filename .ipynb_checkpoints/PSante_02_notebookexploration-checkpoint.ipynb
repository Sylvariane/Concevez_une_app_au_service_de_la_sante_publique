# %% [markdown]
# # Analyses descriptives des données "Open Food Facts"

# %% [markdown]
# ## I - Paramétrage de l'environnement

# %%
# importation des librairies nécessaires

import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
import scipy.stats as stats
import pingouin as pg
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

# %%
def display_circles(pcs, n_comp, pca, axis_ranks, labels=None, label_rotation=0, lims=None):
    for d1, d2 in axis_ranks: # On affiche les 3 premiers plans factoriels, donc les 6 premières composantes
        if d2 < n_comp:

            # initialisation de la figure
            fig, ax = plt.subplots(figsize=(10,10))

            # détermination des limites du graphique
            if lims is not None :
                xmin, xmax, ymin, ymax = lims
            elif pcs.shape[1] < 30 :
                xmin, xmax, ymin, ymax = -1, 1, -1, 1
            else :
                xmin, xmax, ymin, ymax = min(pcs[d1,:]), max(pcs[d1,:]), min(pcs[d2,:]), max(pcs[d2,:])

            # affichage des flèches
            # s'il y a plus de 30 flèches, on n'affiche pas le triangle à leur extrémité
            if pcs.shape[1] < 30 :
                plt.quiver(np.zeros(pcs.shape[1]), np.zeros(pcs.shape[1]),
                   pcs[d1,:], pcs[d2,:], 
                   angles='xy', scale_units='xy', scale=1, color="grey")
                # (voir la doc : https://matplotlib.org/api/_as_gen/matplotlib.pyplot.quiver.html)
            else:
                lines = [[[0,0],[x,y]] for x,y in pcs[[d1,d2]].T]
                ax.add_collection(LineCollection(lines, axes=ax, alpha=.1, color='black'))
            
            # affichage des noms des variables  
            if labels is not None:  
                for i,(x, y) in enumerate(pcs[[d1,d2]].T):
                    if x >= xmin and x <= xmax and y >= ymin and y <= ymax :
                      plt.text(x, y, labels[i], fontsize='14', ha='center', va='center', rotation=label_rotation, color="blue", alpha=0.5)
            
            # affichage du cercle
            an = np.linspace(0, 2 * np.pi, 100)  # Add a unit circle for scale
            plt.plot(np.cos(an), np.sin(an))
            plt.axis('equal')

            # définition des limites du graphique
            plt.xlim(xmin, xmax)
            plt.ylim(ymin, ymax)
        
            # affichage des lignes horizontales et verticales
            plt.plot([-1, 1], [0, 0], color='grey', ls='--')
            plt.plot([0, 0], [-1, 1], color='grey', ls='--')

            # nom des axes, avec le pourcentage d'inertie expliqué
            plt.xlabel('F{} ({}%)'.format(d1+1, round(100*pca.explained_variance_ratio_[d1],1)))
            plt.ylabel('F{} ({}%)'.format(d2+1, round(100*pca.explained_variance_ratio_[d2],1)))

            plt.title("Cercle des corrélations (F{} et F{})".format(d1+1, d2+1))
            plt.show(block=False)

# %%
# paramétrage de la palette de couleurs Seaborn
sns.set_theme(style="ticks", palette="Pastel2")

# %%
filepath = 'datasets/openfoodfacts_clean_median.csv'

# %%
# chargement du fichier
df = pd.read_csv(filepath)
df.head(3)
# Out:
#                 code                                                url  \
# 0  00000000000000225  http://world-en.openfoodfacts.org/product/0000...
# 1      0000000000017  http://world-en.openfoodfacts.org/product/0000...
# 2      0000000000031  http://world-en.openfoodfacts.org/product/0000...
#
#           creator      product_name quantity   brands categories countries  \
# 0  Nutrinet-sante    Jeunes pousses      NaN  Endives        NaN    France
# 1         Kiliweb  Vitória crackers      NaN      NaN        NaN    France
# 2        Isagoofy             Cacao    130 g      NaN        NaN    France
#
#   ingredients_text serving_size  ...  energy-kcal_100g  fat_100g  \
# 0              NaN          NaN  ...               NaN       NaN
# 1              NaN          NaN  ...             375.0       7.0
# 2              NaN          NaN  ...               NaN       NaN
#
#    saturated-fat_100g  carbohydrates_100g  sugars_100g fiber_100g  \
# 0                 NaN                 NaN          NaN        NaN
# 1                3.08                70.1         15.0        NaN
# 2                 NaN                 NaN          NaN        NaN
#
#   proteins_100g sodium_100g created_years last_modified_years
# 0           NaN         NaN          2021                2021
# 1           7.8        0.56          2018                2019
# 2           NaN         NaN          2018                2018
#
# [3 rows x 33 columns]

# %%
df.columns
# Out:
# Index(['code', 'url', 'creator', 'product_name', 'quantity', 'brands',
#        'categories', 'countries', 'ingredients_text', 'serving_size',
#        'serving_quantity', 'additives_n', 'ingredients_from_palm_oil_n',
#        'ingredients_that_may_be_from_palm_oil_n', 'nutriscore_score',
#        'nutriscore_grade', 'pnns_groups_1', 'pnns_groups_2', 'states',
#        'main_category', 'image_url', 'image_ingredients_url',
#        'image_nutrition_url', 'energy-kcal_100g', 'fat_100g',
#        'saturated-fat_100g', 'carbohydrates_100g', 'sugars_100g', 'fiber_100g',
#        'proteins_100g', 'sodium_100g', 'created_years', 'last_modified_years'],
#       dtype='object')

# %%
# suppression des colonnes qui ne vont pas être utiles à l'analyse
col_drop = ['code', 'url', 'creator', 'quantity', 'ingredients_text', 'serving_quantity', 'serving_size', 'states',
            'main_category', 'image_url', 'image_ingredients_url', 'image_nutrition_url'] 

df.drop(col_drop, axis=1, inplace=True)

# %%
# transformation des variables catégorielles en catégorie
col_cat = ["additives_n", "countries", "ingredients_from_palm_oil_n", "ingredients_that_may_be_from_palm_oil_n",
           "nutriscore_score", "nutriscore_grade"]

for col in col_cat:
    df[col] = df[col].astype("category")

# %%
df.shape
# Out:
# (1753668, 21)

# %%
# Suppression des colonnes avec plus de 70% de valeurs manquantes
df = df.loc[:, df.isnull().mean() <.70]

# %%
msno.matrix(df)
# Out:
# <AxesSubplot:>

# %%
# Retrait des valeurs manquantes
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (441774, 20)

# %% [markdown]
# ## II -  Analyses univariées

# %% [markdown]
# On va réaliser une analyse univariée de nos différentes variables pour voir leur comportement. On va commencer par s'intéresser aux variables catégorielles avant de se pencher sur les variables quantitatives.

# %% [markdown]
# ### a) Description des variables qualitatives

# %% [markdown]
# - Les pays

# %%
print('Nombre de pays :', len(df['countries'].unique()))
# Out:
# Nombre de pays : 291

# %%
plt.figure(figsize=(7,5))
sns.countplot(y="countries", data=df, order=pd.value_counts(df['countries']).iloc[:10].index)
plt.ylabel("Pays")
plt.title("Classement des 10 pays les plus représentés dans notre échantillon")
plt.savefig("Présentation/Images/top_10_pays.png")
plt.show()

# %% [markdown]
# Pour la suite de notre étude, on va se pencher sur l'analyse des données uniquement pour la France.

# %%
df_france = df.loc[df['countries'] == 'France']
df_france.shape
# Out:
# (204938, 20)

# %% [markdown]
# - Les types de produits

# %%
print('Nombre de produits :', len(df_france['product_name'].unique()))
# Out:
# Nombre de produits : 135493

# %%
plt.figure(figsize=(7, 5))
sns.countplot(y="product_name", data=df_france, order=pd.value_counts(df_france['product_name']).iloc[:10].index)
plt.ylabel("Produits")
plt.title("Classement des 10 produits les plus présents dans nos données")
plt.savefig("Présentation/Images/top_10_produits.png")
plt.show()

# %% [markdown]
# - Les marques de distributeurs

# %%
print('Nombre de marques :', len(df_france['brands'].unique()))
# Out:
# Nombre de marques : 34011

# %%
plt.figure(figsize=(7, 5))
sns.countplot(y="brands", data=df_france, order=pd.value_counts(df_france['brands']).iloc[:10].index)
plt.ylabel("Marques")
plt.title("Classement des 10 marques les plus représentées dans nos données")
plt.savefig("Présentation/Images/top_10_marques.png")
plt.show()

# %% [markdown]
# - Les années de création et de modification

# %%
print("Nombre d'années de création : ", len(df_france["created_years"].unique()))
print("Année avec le plus d'ajout de produits :", df_france['created_years'].mode()[0])
print("Nombre d'années de modification : ", len(df_france['last_modified_years'].unique()))
print("Année avec le plus de mise à jour de produits :", df_france['last_modified_years'].mode()[0])
# Out:
# Nombre d'années de création :  10
# Année avec le plus d'ajout de produits : 2018
# Nombre d'années de modification :  9
# Année avec le plus de mise à jour de produits : 2021

# %% [markdown]
# ### b) Distribution des variables catégorielles

# %% [markdown]
# Les variables ci-dessous possèdent un nombre de modalités limité. On va donc les représenter sous forme d'histogrammes.

# %%
col_cat = ["additives_n", "ingredients_from_palm_oil_n", "ingredients_that_may_be_from_palm_oil_n",
           "nutriscore_score", "nutriscore_grade", "pnns_groups_1", "pnns_groups_2"]

for col in col_cat:
    sns.countplot(x=col, data=df_france)
    plt.title(col)
    plt.xticks(rotation=45)
    plt.show()

# %%
df_france['nutriscore_grade'] = df_france['nutriscore_grade'].replace("a", "A")
df_france['nutriscore_grade'] = df_france['nutriscore_grade'].replace("b", "B")
df_france['nutriscore_grade'] = df_france['nutriscore_grade'].replace("c", "C")
df_france['nutriscore_grade'] = df_france['nutriscore_grade'].replace("d", "D")
df_france['nutriscore_grade'] = df_france['nutriscore_grade'].replace("e", "E")

# %%
plt.figure(figsize=(7,5))
sns.countplot(y="nutriscore_grade", data=df_france)
plt.ylabel("Nutriscore")
plt.title("Répartition du Nutriscore dans notre échantillon de produits français")
plt.savefig("Présentation/Images/nutriscore.png")
plt.show()

# %% [markdown]
# ### c) Description de la distribution des variables quantitatives

# %% [markdown]
# On va générer des histogrammes pour évaluer la distribution de chacune de nos variables quantitatives.

# %%
for var in df_france.columns:
    if df_france[var].dtypes == 'float64':
        sns.histplot(x=var, data=df_france, kde=True)
        plt.show()

# %% [markdown]
# On accompagne ces visualisations d'un test de normalité. Ici, nous avons choisi le test de Kolmogorov-Smirnov qui est le plus adapté à notre échantillon.

# %%
pg.normality(df_france, method='normaltest', alpha=0.05)
# Out:
#                                  W  pval  normal
# energy-kcal_100g      12061.932024   0.0   False
# fat_100g              87005.389036   0.0   False
# saturated-fat_100g   152098.351145   0.0   False
# carbohydrates_100g    31594.101338   0.0   False
# sugars_100g           67748.120495   0.0   False
# proteins_100g        103403.008982   0.0   False
# sodium_100g          440078.937780   0.0   False
# created_years         23529.266845   0.0   False
# last_modified_years   31307.937282   0.0   False

# %% [markdown]
# On réalise ensuite un test sur l'homogénéité de nos variances dans notre échantillon. Le choix s'est porté sur un test de Levene car il est plus efficace lorsque les distributions ne suivent pas une loi normale. Dans le cas contraire, nous aurions utilisé un test de Bartlett.

# %%
pg.homoscedasticity(df_france, method='levene', alpha=0.05)
# Out:
#                W  pval  equal_var
# levene  0.006207   1.0       True

# %%
plt.figure(figsize=(7,7))
sns.histplot(x="carbohydrates_100g", data=df_france, kde=True)
plt.title('Distribution des carbohydrates dans notre échantillon')
plt.ylabel("Carbohydrates pour 100g")
plt.savefig("Présentation/Images/carbohydrates_distribution.png")
plt.show()

# %% [markdown]
# **Conclusion :**
#
# Aucune de nos variables ne suit une loi normale. En revanche, selon le test de Levene avec un alpha à 0.05, les variances de nos variables quantitatives sont homogènes.

# %% [markdown]
# ### d) Analyses descriptives des variables

# %% [markdown]
# #### Analyses graphiques des variables

# %% [markdown]
# Après avoir regardé la distribution de nos variables, on va s'intéresser à leur comportement. On va donc représenter ces dernières sous forme de boîte à moustache pour avoir une idée rapide de la manière dont elle se comporte.

# %%
for var in df_france.columns:
    if df_france[var].dtypes == 'float64':
        sns.boxplot(x=var, data=df_france)
        plt.title(var)
        plt.show()

# %%
plt.figure(figsize=(7,7))
sns.boxplot(y="carbohydrates_100g", data=df_france)
plt.title('Description statistique des carbohydrates dans notre échantillon')
plt.ylabel("Carbohydrates pour 100g")
plt.savefig("Présentation/Images/carbohydrates_boxplot.png")
plt.show()

# %% [markdown]
# #### Analyses statistiques des variables

# %% [markdown]
# On accompagne notre analyse visuelle par les données chiffrées décrivant nos données.

# %%
df_france.describe()
# Out:
#        energy-kcal_100g       fat_100g  saturated-fat_100g  \
# count     204938.000000  204938.000000       204938.000000
# mean         276.230943      14.879635            5.703340
# std          192.830958      18.642507            8.642026
# min            0.000000       0.000000            0.000000
# 25%          110.000000       1.200000            0.300000
# 50%          252.000000       8.000000            2.100000
# 75%          404.000000      23.000000            8.100000
# max         1000.000000     100.000000          100.000000
#
#        carbohydrates_100g    sugars_100g  proteins_100g    sodium_100g  \
# count       204938.000000  204938.000000  204938.000000  204938.000000
# mean            25.982180      13.109456       8.409229       0.380179
# std             26.835898      18.750287       8.847549       0.936809
# min              0.000000       0.000000       0.000000       0.000000
# 25%              2.900000       0.800000       1.600000       0.020000
# 50%             13.000000       3.700000       6.100000       0.200000
# 75%             51.000000      18.100000      12.000000       0.480000
# max            100.000000     100.000000     100.000000      50.000000
#
#        created_years  last_modified_years
# count  204938.000000        204938.000000
# mean     2017.385639          2020.122871
# std         1.595366             0.970472
# min      2012.000000          2013.000000
# 25%      2017.000000          2020.000000
# 50%      2018.000000          2020.000000
# 75%      2018.000000          2021.000000
# max      2021.000000          2021.000000

# %% [markdown]
# ## III - Hypothèses de travail

# %% [markdown]
# Notre jeu de données est composée de différentes variables :
# - Des variables en lien avec l'identification des produits (noms, endroits où ils sont commercialisés, date d'ajout dans la base, date de modification dans la base)
# - Des variables qui mesurent la qualité des produits (nutriscore)
# - Des variables sur les différentes valeurs nutrionnelles du produit (graisse, graisse saturée, carbohydrates, sucres, fibres, protéines, sel)
# - Des variables sur l'énergie que l'on trouve dans chaque produit (énergie en kcal)
#
# On peut se demander si la quantité d'ingrédients en lien avec l'huile de palme va avoir un impact sur le nutriscore et donc la composition nutrionnelle des aliments.
#
# On peut aussi se demander si l'utilisation des données en lien avec les valeurs nutrionnelles du produit, l'énergie et sa composition peuvent être intéressantes à utiliser pour développer un score global que l'on pourra imputer à d'autres aliments.

# %% [markdown]
# ## IV - Analyses bivariées des variables

# %% [markdown]
# ### a) Analyses bivariées des variables quantitatives

# %% [markdown]
# #### Corrélation entre les variables quantitatives

# %% [markdown]
# On va d'abord étudier les corrélations entre les différentes variables à l'aide d'une matrice de corrélation.

# %%
corr_matrix = df_france.corr()
mask = np.triu(corr_matrix)

plt.figure(figsize=(15,15))
sns.heatmap(corr_matrix, cmap="coolwarm", mask=mask, linewidths=.5, annot=True, cbar=True, square=True)
plt.title("Matrice de corrélation des variables quantitatives")
plt.savefig("Présentation/Images/matrice_corr.png")
plt.show()

# %% [markdown]
# La matrice de corrélation permet de voir les corrélations qui existent entre les différentes variables quantitatives. On ne va donc pas s'intéresser aux variables qualitatives comme les différents scores que l'on a pu voir plus haut.
# On remarque une forte corrélation positive entre la **quantité d'énergie en kcal pour 100g** et la **quantité de graisses pour 100g** *(0.8)*, la **quantité de graisses saturées pour 100g** *(0.59)* et la **quantité de carbohydrates pour 100g** *(0.4)*. De plus, on remarque une forte corrélation positive entre la **quantité de graisses pour 100g** et la **quantité de graisses saturées pour 100g** *(0.71)*. Enfin, on observe une dernière corrélation positive moyenne entre la **quantité de sucres pour 100g** et la **quantité de carbohydrates pour 100g** *(0.69)*.

# %% [markdown]
# On va donc réaliser une régression linéaire en partant de ces corrélations pour mieux voir ce qui unit ces variables

# %% [markdown]
# #### Analyse de régression entre variables quantitatives

# %% [markdown]
# - Energie en Kcal et quantité de graisses pour 100g

# %%
sns.lmplot(x="energy-kcal_100g", y="fat_100g", data=df_france)
plt.title("Régression entre l'énergie en Kcal et la quantité de graisses")
plt.xlim(df_france["energy-kcal_100g"].min(), df_france["energy-kcal_100g"].max())
plt.ylim(df_france["fat_100g"].min(), df_france["fat_100g"].max())
plt.show()

# %%
pg.linear_regression(X=df_france["energy-kcal_100g"], y=df_france["fat_100g"], add_intercept=True, alpha=0.05)
# Out:
#               names      coef        se           T  pval        r2    adj_r2  \
# 0         Intercept -6.534497  0.042987 -152.011877   0.0  0.642986  0.642984
# 1  energy-kcal_100g  0.077523  0.000128  607.528708   0.0  0.642986  0.642984
#
#    CI[2.5%]  CI[97.5%]
# 0 -6.618750  -6.450244
# 1  0.077272   0.077773

# %%
sns.lmplot(x="energy-kcal_100g", y="saturated-fat_100g", data=df_france)
plt.title("Régression entre l'énergie en Kcal et la quantité de graisses saturées")
plt.xlim(df_france["energy-kcal_100g"].min(), df_france["energy-kcal_100g"].max())
plt.ylim(df_france["saturated-fat_100g"].min(), df_france["saturated-fat_100g"].max())
plt.show()

# %%
pg.linear_regression(X=df_france["energy-kcal_100g"], y=df_france["saturated-fat_100g"], add_intercept=True, alpha=0.05)
# Out:
#               names      coef        se           T  pval        r2    adj_r2  \
# 0         Intercept -1.655842  0.026818  -61.743334   0.0  0.353376  0.353373
# 1  energy-kcal_100g  0.026641  0.000080  334.658331   0.0  0.353376  0.353373
#
#    CI[2.5%]  CI[97.5%]
# 0 -1.708405  -1.603279
# 1  0.026485   0.026797

# %%
sns.lmplot(x="energy-kcal_100g", y="carbohydrates_100g", data=df)
plt.title("Régression entre l'énergie en Kcal et la quantité de carbohydrates")
plt.xlim(df_france["energy-kcal_100g"].min(), df_france["energy-kcal_100g"].max())
plt.ylim(df_france["carbohydrates_100g"].min(), df_france["carbohydrates_100g"].max())
plt.show()

# %%
pg.linear_regression(X=df_france["energy-kcal_100g"], y=df_france["carbohydrates_100g"], add_intercept=True, alpha=0.05)
# Out:
#               names       coef        se           T  pval        r2   adj_r2  \
# 0         Intercept  10.653588  0.094974  112.174167   0.0  0.158994  0.15899
# 1  energy-kcal_100g   0.055492  0.000282  196.834028   0.0  0.158994  0.15899
#
#     CI[2.5%]  CI[97.5%]
# 0  10.467442  10.839734
# 1   0.054939   0.056045

# %%
sns.lmplot(x="energy-kcal_100g", y="sugars_100g", data=df_france)
plt.title("Régression entre l'énergie en Kcal et la quantité de sucres")
plt.xlim(df_france["energy-kcal_100g"].min(), df_france["energy-kcal_100g"].max())
plt.ylim(df_france["sugars_100g"].min(), df_france["sugars_100g"].max())
plt.show()

# %%
pg.linear_regression(X=df_france["energy-kcal_100g"], y=df_france["sugars_100g"], add_intercept=True, alpha=0.05)
# Out:
#               names      coef        se           T  pval        r2    adj_r2  \
# 0         Intercept  5.943827  0.069737   85.232038   0.0  0.071171  0.071166
# 1  energy-kcal_100g  0.025941  0.000207  125.311821   0.0  0.071171  0.071166
#
#    CI[2.5%]  CI[97.5%]
# 0  5.807144   6.080510
# 1  0.025535   0.026346

# %% [markdown]
# - Graisses et graisses saturées

# %%
sns.lmplot(x="fat_100g", y="saturated-fat_100g", data=df_france)
plt.title("Régression entre la quantité de graisses et la quantité de graisses saturées")
plt.xlim(df_france["fat_100g"].min(), df_france["fat_100g"].max())
plt.ylim(df_france["saturated-fat_100g"].min(), df_france["saturated-fat_100g"].max())
plt.show()

# %%
pg.linear_regression(X=df_france["fat_100g"], y=df_france["saturated-fat_100g"], add_intercept=True, alpha=0.05)
# Out:
#        names      coef        se           T  pval        r2    adj_r2  \
# 0  Intercept  0.775191  0.017090   45.360403   0.0  0.510459  0.510456
# 1   fat_100g  0.331201  0.000716  462.269045   0.0  0.510459  0.510456
#
#    CI[2.5%]  CI[97.5%]
# 0  0.741696   0.808686
# 1  0.329797   0.332605

# %% [markdown]
# - Carbohydrates et sucres

# %%
sns.lmplot(x="sugars_100g", y="carbohydrates_100g", data=df)
plt.title("Régression entre la quantité de sucres et la quantité de carbohydrates")
plt.xlim(df_france["sugars_100g"].min(), df_france["sugars_100g"].max())
plt.ylim(df_france["carbohydrates_100g"].min(), df_france["carbohydrates_100g"].max())
plt.show()

# %%
pg.linear_regression(X=df_france["sugars_100g"], y=df_france["carbohydrates_100g"], add_intercept=True, alpha=0.05)
# Out:
#          names       coef        se           T  pval        r2    adj_r2  \
# 0    Intercept  13.102693  0.052598  249.109003   0.0  0.471207  0.471204
# 1  sugars_100g   0.982458  0.002299  427.338310   0.0  0.471207  0.471204
#
#     CI[2.5%]  CI[97.5%]
# 0  12.999601  13.205784
# 1   0.977952   0.986964

# %% [markdown]
# ### b) Analyses bivariées des variables qualitatives et quantitatives

# %% [markdown]
# #### Analyses entre la quantité de graisse et les différentes variables qualitatives

# %%
plt.figure(figsize=(10, 7))
sns.boxplot(x="nutriscore_grade", y="fat_100g", data=df_france)
plt.xlabel("Nutriscore")
plt.ylabel("Graisses pour 100g")
plt.title("Lien entre la quantité de graisse et le nutriscore")
plt.savefig('Présentation/Images/graisse_vs_nutriscore.png')
plt.show()

# %%
pg.anova(data=df_france, dv="fat_100g", between="nutriscore_grade")
# Out:
#              Source  ddof1   ddof2             F  p-unc       np2
# 0  nutriscore_grade      4  204933  11119.165205    0.0  0.178328

# %%
plt.figure(figsize=(10, 7))
sns.boxplot(x="ingredients_from_palm_oil_n", y="fat_100g", data=df_france)
plt.xlabel("Nombre d'ingrédients dérivé de l'huile de palme")
plt.ylabel("Graisses pour 100g")
plt.title("Lien entre la quantité de graisse et le nombre d'ingrédients issus de l'huile de palme")
plt.savefig("Présentation/Images/huile_de_palm_vs_graisses.png")
plt.show()

# %%
pg.anova(data=df_france, dv="fat_100g", between="ingredients_from_palm_oil_n")
# Out:
#                         Source  ddof1   ddof2          F          p-unc  \
# 0  ingredients_from_palm_oil_n      2  204935  419.25301  1.959808e-182
#
#         np2
# 0  0.004075

# %%
plt.figure(figsize=(10, 7))
sns.boxplot(x="ingredients_that_may_be_from_palm_oil_n", y="fat_100g", data=df_france)
plt.title("Lien entre la quantité de graisse et le nombre d'ingrédients qui pouvait être issus de l'huile de palme")
plt.show()

# %%
pg.anova(data=df_france, dv="fat_100g", between="ingredients_that_may_be_from_palm_oil_n")
# Out:
#                                     Source  ddof1   ddof2          F  \
# 0  ingredients_that_may_be_from_palm_oil_n      5  204932  18.603853
#
#           p-unc       np2
# 0  1.574078e-18  0.000454

# %% [markdown]
# #### Analyses entre la quantité de sucre et les différentes variables qualitatives

# %%
plt.figure(figsize=(10, 7))
sns.boxplot(x="nutriscore_grade", y="sugars_100g", data=df_france)
plt.title("Lien entre la quantité de sucre et le nutriscore")
plt.xlabel("Nutriscore")
plt.ylabel("Sucres pour 100g")
plt.savefig("Présentation/Images/nutriscore_vs_sucres.png")
plt.show()

# %%
pg.anova(data=df_france, dv="sugars_100g", between="nutriscore_grade")
# Out:
#              Source  ddof1   ddof2           F  p-unc       np2
# 0  nutriscore_grade      4  204933  8008.39408    0.0  0.135182

# %%
plt.figure(figsize=(10, 7))
sns.boxplot(x="ingredients_from_palm_oil_n", y="sugars_100g", data=df_france)
plt.title("Lien entre la quantité de sucre et le nombre d'ingrédients issus de l'huile de palme")
plt.xlabel("Nombre d'ingrédients dérivée de l'huile de palme")
plt.ylabel("Sucres pour 100g")
plt.savefig("Présentation/Images/palm_oil_vs_sugars.png")
plt.show()

# %%
pg.anova(data=df_france, dv="sugars_100g", between="ingredients_from_palm_oil_n")
# Out:
#                         Source  ddof1   ddof2            F  p-unc      np2
# 0  ingredients_from_palm_oil_n      2  204935  1751.899509    0.0  0.01681

# %%
plt.figure(figsize=(10, 7))
sns.boxplot(x="ingredients_that_may_be_from_palm_oil_n", y="sugars_100g", data=df_france)
plt.title("Lien entre la quantité de graisse et le nombre d'ingrédients qui pouvait être issus de l'huile de palme")
plt.show()

# %%
pg.anova(data=df, dv="sugars_100g", between="ingredients_that_may_be_from_palm_oil_n")
# Out:
#                                     Source  ddof1   ddof2           F  p-unc  \
# 0  ingredients_that_may_be_from_palm_oil_n      5  441768  353.283445    0.0
#
#         np2
# 0  0.003983

# %% [markdown]
# #### Analyses entre la quantité de protéines et les différentes variables qualitatives

# %%
plt.figure(figsize=(10, 7))
sns.boxplot(x="nutriscore_grade", y="proteins_100g", data=df_france)
plt.title("Lien entre la quantité de protéines et le nutriscore")
plt.xlabel("Nutriscore")
plt.ylabel("Protéines pour 100g")
plt.savefig("Présentation/Images/proteins_vs_nutriscore.png")
plt.show()

# %%
pg.anova(data=df_france, dv="proteins_100g", between="nutriscore_grade")
# Out:
#              Source  ddof1   ddof2            F  p-unc       np2
# 0  nutriscore_grade      4  204933  1104.929122    0.0  0.021111

# %%
plt.figure(figsize=(10, 7))
sns.boxplot(x="ingredients_from_palm_oil_n", y="proteins_100g", data=df_france)
plt.xlabel("Nombre d'ingrédients provenant de l'huile de palme")
plt.ylabel("Protéines pour 100g")
plt.title("Lien entre la quantité de protéines et le nombre d'ingrédients issus de l'huile de palme")
plt.savefig("Présentation/Images/palm_oil_vs_proteins.png")
plt.show()

# %%
pg.anova(data=df, dv="proteins_100g", between="ingredients_from_palm_oil_n")
# Out:
#                         Source  ddof1   ddof2          F         p-unc  \
# 0  ingredients_from_palm_oil_n      2  441771  130.26418  2.777542e-57
#
#         np2
# 0  0.000589

# %%
plt.figure(figsize=(10, 7))
sns.boxplot(x="ingredients_that_may_be_from_palm_oil_n", y="proteins_100g", data=df_france)
plt.title("Lien entre la quantité de protéines et le nombre d'ingrédients issus de l'huile de palme")
plt.show()

# %%
pg.anova(data=df_france, dv="proteins_100g", between="ingredients_that_may_be_from_palm_oil_n")
# Out:
#                                     Source  ddof1   ddof2           F  \
# 0  ingredients_that_may_be_from_palm_oil_n      5  204932  158.734965
#
#            p-unc       np2
# 0  5.780812e-169  0.003858

# %% [markdown]
# #### Analyses entre la quantité de carbohydrates et les différentes variables quanlitatives

# %%
plt.figure(figsize=(10, 7))
sns.boxplot(x="nutriscore_grade", y="carbohydrates_100g", data=df_france)
plt.title("Lien entre la quantité de carbohydrates et le nutriscore")
plt.xlabel("Nutriscore")
plt.ylabel("Carbohydrates pour 100g")
plt.savefig("Présentation/Images/nutriscore_vs_carbohydrates.png")
plt.show()

# %%
pg.anova(data=df_france, dv="carbohydrates_100g", between="nutriscore_grade")
# Out:
#              Source  ddof1   ddof2            F  p-unc       np2
# 0  nutriscore_grade      4  204933  2029.685365    0.0  0.038107

# %%
plt.figure(figsize=(10, 7))
sns.boxplot(x="ingredients_from_palm_oil_n", y="carbohydrates_100g", data=df_france)
plt.title("Lien entre la quantité de carbohydrates et le nombre d'ingrédients issus de l'huile de palme")
plt.xlabel("Nombre d'ingrédient provenant de l'huile de palme")
plt.ylabel("Carbohydrates pour 100g")
plt.savefig("Présentation/Images/carbohydrates_vs_palm_oil.png")
plt.show()

# %%
pg.anova(data=df_france, dv="carbohydrates_100g", between="ingredients_from_palm_oil_n")
# Out:
#                         Source  ddof1   ddof2            F  p-unc       np2
# 0  ingredients_from_palm_oil_n      2  204935  2955.179051    0.0  0.028032

# %%
plt.figure(figsize=(10, 7))
sns.boxplot(x="ingredients_that_may_be_from_palm_oil_n", y="carbohydrates_100g", data=df_france)
plt.title("Lien entre la quantité de carbohydrates et le nombre d'ingrédients issus de l'huile de palme")
plt.show()

# %%
pg.anova(data=df_france, dv="carbohydrates_100g", between="ingredients_that_may_be_from_palm_oil_n")
# Out:
#                                     Source  ddof1   ddof2           F  p-unc  \
# 0  ingredients_that_may_be_from_palm_oil_n      5  204932  764.413988    0.0
#
#         np2
# 0  0.018309

# %% [markdown]
# #### Analyses entre la quantité de sel et les différentes variables qualitatives

# %%
plt.figure(figsize=(10, 7))
sns.boxplot(x="nutriscore_grade", y="sodium_100g", data=df_france)
plt.title("Lien entre la quantité de sodium et le nutriscore")
plt.xlabel("Nutriscore")
plt.ylabel("sodium pour 100g")
plt.savefig("Présentation/Images/sodium_vs_nutriscore.png")
plt.show()

# %%
pg.anova(data=df_france, dv="sodium_100g", between="nutriscore_grade")
# Out:
#              Source  ddof1   ddof2            F  p-unc       np2
# 0  nutriscore_grade      4  204933  1450.414989    0.0  0.027531

# %%
plt.figure(figsize=(10, 7))
sns.boxplot(x="ingredients_from_palm_oil_n", y="sodium_100g", data=df_france)
plt.title("Lien entre la quantité de sodium et le nombre d'ingrédients issus de l'huile de palme")
plt.xlabel("Nombre d'ingrédient provenant de l'huile de palme")
plt.ylabel("sodium pour 100g")
plt.savefig("Présentation/Images/sodium_vs_palm_oil.png")
plt.show()

# %%
pg.anova(data=df_france, dv="sodium_100g", between="ingredients_from_palm_oil_n")
# Out:
#                         Source  ddof1   ddof2         F     p-unc       np2
# 0  ingredients_from_palm_oil_n      2  204935  0.824418  0.438492  0.000008

# %%
plt.figure(figsize=(10, 7))
sns.boxplot(x="ingredients_that_may_be_from_palm_oil_n", y="sodium_100g", data=df_france)
plt.title("Lien entre la quantité de sodium et le nombre d'ingrédients issus de l'huile de palme")
plt.show()

# %%
pg.anova(data=df_france, dv="sodium_100g", between="ingredients_that_may_be_from_palm_oil_n")
# Out:
#                                     Source  ddof1   ddof2          F  \
# 0  ingredients_that_may_be_from_palm_oil_n      5  204932  15.291894
#
#           p-unc       np2
# 0  4.642910e-15  0.000373

# %% [markdown]
# #### Analyses entre la quantité d'énergie et les différentes variables qualitatives

# %%
plt.figure(figsize=(10, 7))
sns.boxplot(x="nutriscore_grade", y="energy-kcal_100g", data=df_france)
plt.title("Lien entre la quantité d'énergie et le nutriscore")
plt.xlabel("Nutriscore")
plt.ylabel("Energie en kcal pour 100g")
plt.savefig("Présentation/Images/energy-kcal_vs_nutriscore.png")
plt.show()

# %%
pg.anova(data=df_france, dv="energy-kcal_100g", between="nutriscore_grade")
# Out:
#              Source  ddof1   ddof2             F  p-unc       np2
# 0  nutriscore_grade      4  204933  14397.541689    0.0  0.219372

# %%
plt.figure(figsize=(10, 7))
sns.boxplot(x="ingredients_from_palm_oil_n", y="energy-kcal_100g", data=df_france)
plt.title("Lien entre la quantité d'énergie et le nombre d'ingrédients issus de l'huile de palme")
plt.xlabel("Nombre d'ingrédients provenant de l'huile de palme")
plt.ylabel("Energie en kcal pour 100g")
plt.savefig("Présentation/Images/energy-kcal_vs_palm_oil.png")
plt.show()

# %%
pg.anova(data=df_france, dv="energy-kcal_100g", between="ingredients_from_palm_oil_n")
# Out:
#                         Source  ddof1   ddof2            F  p-unc       np2
# 0  ingredients_from_palm_oil_n      2  204935  2078.500722    0.0  0.019881

# %%
plt.figure(figsize=(10, 7))
sns.boxplot(x="ingredients_that_may_be_from_palm_oil_n", y="energy-kcal_100g", data=df_france)
plt.title("Lien entre la quantité d'énergie et le nombre d'ingrédients issus de l'huile de palme")
plt.show()

# %%
pg.anova(data=df_france, dv="energy-kcal_100g", between="ingredients_that_may_be_from_palm_oil_n")
# Out:
#                                     Source  ddof1   ddof2           F  \
# 0  ingredients_that_may_be_from_palm_oil_n      5  204932  273.571391
#
#            p-unc      np2
# 0  1.219081e-292  0.00663

# %% [markdown]
# ## c) Analyses bivariées entre les variables qualitatives

# %% [markdown]
# - Nutriscore et nombre d'additifs

# %%
expected, observed, stats = pg.chi2_independence(data=df_france, x="additives_n", y="nutriscore_grade")
stats.round(3)
# Out:
#                  test  lambda       chi2    dof  pval  cramer  power
# 0             pearson   1.000  11855.289  112.0   0.0   0.120    1.0
# 1        cressie-read   0.667  11848.097  112.0   0.0   0.120    1.0
# 2      log-likelihood   0.000  12088.351  112.0   0.0   0.121    1.0
# 3       freeman-tukey  -0.500        NaN  112.0   NaN     NaN    NaN
# 4  mod-log-likelihood  -1.000        inf  112.0   0.0     inf    1.0
# 5              neyman  -2.000        NaN  112.0   NaN     NaN    NaN

# %% [markdown]
# - Nutriscore et nombre d'ingrédients provenant de l'huile de palme

# %%
contingency = pd.crosstab(index=df_france["nutriscore_grade"], columns=df_france["ingredients_from_palm_oil_n"], margins=True)

# %%
plt.figure(figsize=(10,7))
sns.heatmap(contingency, annot=True, cmap="Spectral")
plt.xlabel("Nombre d'ingrédients dérivé de l'huile de palme")
plt.ylabel("Nutriscore")
plt.yticks(rotation=360)
plt.title("Tableau de contingence entre le Nutriscore et le nombre d'ingrédients dérivé de l'huile de palme")
plt.savefig("Présentation/Images/Contingency_tab.png")
plt.show()

# %%
expected, observed, stats = pg.chi2_independence(data=df_france, x="nutriscore_grade", y="ingredients_from_palm_oil_n")
stats.round(3)
# Out:
#                  test  lambda      chi2  dof  pval  cramer  power
# 0             pearson   1.000  4171.319  8.0   0.0   0.101    1.0
# 1        cressie-read   0.667  4107.251  8.0   0.0   0.100    1.0
# 2      log-likelihood   0.000  4271.791  8.0   0.0   0.102    1.0
# 3       freeman-tukey  -0.500       NaN  8.0   NaN     NaN    NaN
# 4  mod-log-likelihood  -1.000       inf  8.0   0.0     inf    1.0
# 5              neyman  -2.000       NaN  8.0   NaN     NaN    NaN

# %% [markdown]
# - Nutriscore et nombre d'ingrédients pouvant provenir de l'huile de palme

# %%
expected, observed, stats = pg.chi2_independence(data=df_france, x="nutriscore_grade", y="ingredients_that_may_be_from_palm_oil_n")
stats.round(3)
# Out:
#                  test  lambda      chi2   dof  pval  cramer  power
# 0             pearson   1.000  1902.286  20.0   0.0   0.048    1.0
# 1        cressie-read   0.667  1952.454  20.0   0.0   0.049    1.0
# 2      log-likelihood   0.000  2101.811  20.0   0.0   0.051    1.0
# 3       freeman-tukey  -0.500       NaN  20.0   NaN     NaN    NaN
# 4  mod-log-likelihood  -1.000       inf  20.0   0.0     inf    1.0
# 5              neyman  -2.000       NaN  20.0   NaN     NaN    NaN

# %% [markdown]
# ## V - Réduction de dimensions

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

n_comp = 2

scaler = StandardScaler()
pca = PCA(n_components=n_comp)


data = df_france[["additives_n", 'energy-kcal_100g', "saturated-fat_100g", "fat_100g","sugars_100g", "carbohydrates_100g",
                   'proteins_100g', 'sodium_100g', "ingredients_from_palm_oil_n"]]

X = data.values
features = data.columns
X_scaled = scaler.fit_transform(X)
pca_components = pca.fit_transform(X_scaled)
pcs = pca.components_

# %%
display_circles(pcs, n_comp, pca, [(0,1),(2,3)], labels = np.array(features))

# %% [markdown]
# - F1 (25.2%) : energy-kcal_100g, saturated-fat_100g, fat_100g
# - F2 (21.2%) : carbohydrates_100g (-), sugars_100g (-), ingredients_from_palm_oil_n (-)
#
# => 46.4% de variance expliquée

# %% [markdown]
# ## VI - Apprentissage non-supervisée

# %% [markdown]
# ### a) Définition de l'algorithme

# %%
from sklearn.cluster import KMeans
from yellowbrick.cluster.elbow import KElbowVisualizer
from sklearn.metrics import silhouette_score, davies_bouldin_score
from yellowbrick.style import set_palette
set_palette('sns_pastel')

# %%
# Instantiate the clustering model and visualizer
model = KMeans()
visualizer = KElbowVisualizer(
    model, k=(2,7), metric='distortion', timings=False
)

visualizer.fit(X)        # Fit the data to the visualizer
visualizer.show()        # Finalize and render the figure
# Out:
# <AxesSubplot:title={'center':'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %%
# paramétrage de la palette de couleurs Seaborn
sns.set_theme(style="ticks", palette="Pastel2")

# %%
km = KMeans(n_clusters=3)

#Prédiction
label = km.fit_predict(pca_components)
 
centroids = km.cluster_centers_
u_labels = np.unique(label)

#Représentation graphique:

plt.figure(figsize=(10,10))
for i in u_labels:
    plt.scatter(pca_components[label == i , 0] , pca_components[label == i , 1] , label = i)
plt.scatter(centroids[:,0] , centroids[:,1] , s = 80, alpha = 0.8, color = 'k')
plt.legend()
plt.title('Représentation des clusters du K-Means')
plt.savefig("Présentation/Images/representation_kmeans.png")
plt.show()

# %%
from sklearn.pipeline import Pipeline

my_model = Pipeline([('scaler', StandardScaler()), 
                     ('kmeans', KMeans(n_clusters=3))])
my_model.fit(X_scaled)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()), ('kmeans', KMeans(n_clusters=3))])

# %%
import joblib
 
# Sauvegarde du modèle
joblib.dump(my_model, 'nutravel_model.pkl')
# Out:
# ['nutravel_model.pkl']

# %% [markdown]
# ### b) Analyses des clusters obtenus

# %%
df_france['Clusters'] = km.labels_

# %%
print("Score de silhouette :", silhouette_score(pca_components,labels=km.labels_).round(3))
# Out:
# Score de silhouette : 0.48

# %%
print("Score de Davies-Bouldin :", davies_bouldin_score(pca_components, labels=km.labels_).round(3))
# Out:
# Score de Davies-Bouldin : 0.781

# %%
print("Nombre de produits :", df_france['product_name'].loc[df_france['Clusters'] == 0].count())
# Out:
# Nombre de produits : 112921

# %%
print("Nombre de produits :", df_france['product_name'].loc[df_france['Clusters'] == 1].count())
# Out:
# Nombre de produits : 35230

# %%
print("Nombre de produits :", df_france['product_name'].loc[df_france['Clusters'] == 2].count())
# Out:
# Nombre de produits : 56787

# %%
plt.figure(figsize=(10,5))
sns.countplot(x="Clusters", data=df_france)
plt.xlabel("Clusters du K-Means")
plt.title("Répartition des produits dans les clusters")
plt.savefig("Présentation/Images/repartition_kmeans.png")
plt.show()

# %%
stats_descr = df_france.groupby("Clusters").mean().round(3)
stats_descr.drop(['created_years', 'last_modified_years'], axis=1, inplace=True)
stats_descr
# Out:
#           energy-kcal_100g  fat_100g  saturated-fat_100g  carbohydrates_100g  \
# Clusters
# 0                  143.869     5.774               1.853              13.885
# 1                  498.533    44.141              16.980               9.200
# 2                  401.519    14.833               6.364              60.448
#
#           sugars_100g  proteins_100g  sodium_100g
# Clusters
# 0               4.752          7.855        0.420
# 1               4.232         14.812        0.544
# 2              35.235          5.539        0.200

# %%
plt.figure(figsize=(10,5))
sns.countplot(x="Clusters", hue="nutriscore_grade", data=df_france)
plt.title("Répartition des produits selon le nutriscore")
plt.legend()
plt.savefig("Présentation/Images/repartition_produits_nutriscore_cluster.png")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.countplot(x="Clusters", hue="ingredients_from_palm_oil_n", data=df_france)
plt.title("Répartition des produits selon le nombre d'ingrédients pouvant provenir de l'huile de palme")
plt.legend(loc="best")
plt.savefig("Présentation/Images/repartition_produits_palm_oil_cluster.png")
plt.show()

# %%
sns.boxplot(x="Clusters", y="energy-kcal_100g", data=df_france)
plt.show()

# %%
sns.boxplot(x="Clusters", y="saturated-fat_100g", data=df_france)
plt.show()

# %%
sns.boxplot(x="Clusters", y="fat_100g", data=df_france)
plt.show()

# %%
sns.boxplot(x="Clusters", y="sugars_100g", data=df_france)
plt.show()

# %%
sns.boxplot(x="Clusters", y="carbohydrates_100g", data=df_france)
plt.show()

# %%
sns.boxplot(x="Clusters", y="proteins_100g", data=df_france)
plt.show()

# %%
sns.boxplot(x="Clusters", y="sodium_100g", data=df_france)
plt.show()

# %% [markdown]
# ### c) Prédiction du cluster d'appartenance d'un produit

# %%
produit = df.loc[df["product_name"] == "Топено сирене с пушена шунка"]

# %% [markdown]
# ![produit_bulgarie.jpg](attachment:75ea6858-9eb3-4cfb-b1a8-024a9cc42792.jpg)
#
# Plus d'informations : [ici](!https://www.supermag.bg/food_products/mlechni-produkti/Topeno_sirene_i_izvara/view?iid=116537)

# %%
produit = produit[['additives_n', 'ingredients_from_palm_oil_n', 'energy-kcal_100g', 'fat_100g', 'saturated-fat_100g',
            'carbohydrates_100g', 'sugars_100g', 'proteins_100g', 'sodium_100g']]

# %%
print(produit)
# Out:
#         additives_n ingredients_from_palm_oil_n  energy-kcal_100g  fat_100g  \
# 1281104           6                           0             295.0      27.0
#
#          saturated-fat_100g  carbohydrates_100g  sugars_100g  proteins_100g  \
# 1281104                17.0                 3.0          3.0           10.0
#
#          sodium_100g
# 1281104          0.8

# %%
nutravel = joblib.load('nutravel_model.pkl')
print(nutravel.predict(produit))
# Out:
# [2]
